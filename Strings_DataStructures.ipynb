# %% [markdown]
# # string in python
# 1.string is collection of information or collection of data enclosed by " "or''

# %%
#create Tstring
name="sivaji"
info='welcome to TIA'
print(name)
print(info)
print(type(name))
print(type(info))
# Out:
# sivaji
# welcome to TIA
# <class 'str'>
# <class 'str'>

# %%
#multline string
info ="""my self shive
i am learing python programming
python with data analysis
python with m1/ai
"""
print(info)
print(type(info))
# Out:
# my self shive
# i am learing python programming
# python with data analysis
# python with m1/ai
#
# <class 'str'>

# %%
# concentration - adding two or more strings
a="python"
b="programming"
print(a+" "+b)

# %%
# repeating string
name="python program"
print(name*10)
# Out:
# python programpython programpython programpython programpython programpython programpython programpython programpython programpython program

# %%
# accesing characte's from string
#index based accesing characters from strings
#index are 2 types 1.forward index 2.backward(negative index)
#forward index-read sting from left to right (0,1,2....n)
#negative index-string start from right to left(-1,-2......-n)

# %%
data="python programming"
print(data)
print(data[0])
print(data[-1])
# Out:
# python programming
# p
# g

# %%
#slicing -accesing group of characters from string - [startindex:endindex-1]
data="python programming"
print(data)
print(data[0:5])
# Out:
# python programming
# pytho
