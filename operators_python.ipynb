# %% [markdown]
# # operators in python
#
# ## python have 6 types of operators
# 1.arthematic operators
# 2.assignment operators
# 3.comparision operators
# 4.logical operators
# 5.membership operators
# 6.identity operators

# %%
#arthamatic operators - +,-,*,/,//,%
a=10
b=20
c=30
d=40
print(a+b)
print(b-d)
print(a*c)
print(b/a)
print(b//a)
# Out:
# 30
# -20
# 300
# 2.0
# 2

# %%
x=98
y=45
z=67
print(x+y)
print(x+z)
print(x-y)
print(z-y)
print(x*y)
print(z*x)
print(x/z)
print(y//z)
print(x//z)
# Out:
# 143
# 165
# 53
# 22
# 4410
# 6566
# 1.462686567164179
# 0
# 1

# %%
#assignment operators +=,-=,*=,/,//=,%=

# %%
a=10
a+=10
print(a)

# %%
a=25
a-=50
print(a)

# %%
c=100
c/=15
print(c)

# %%
# comparision operators - >,<,>=,<=,==,!= (return true or false)
a=5
b=10
x=10
c=20
d=30
print(a>b)
print(b<c)
print(b==x)
print(b!=c)

# %%
# logical operator - and,or,not
# and - this operator checking all condition are true result is true rest cases failed
# or - this operator check either one conditions true true then result true rest cases failed 
# not -

# %%
# membership operators - checking members are present in that sequence or collection - in,not in
name=["shiva","vikas","divya","alok"]
print("alok" in name)
