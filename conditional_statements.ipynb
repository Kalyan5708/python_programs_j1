# %% [markdown]
# # conditional statements in python
# 1. phython have 4 types of conditional statements
# 2.`if` statement
# 3.`elif`statement
# 4.`else`statement
# 5.`nested`statement
#
# ```python
# if(condition):
#     statements
#     statements..
# ```
#
# ```python if,else
# if(condition):
#     statements
#     statements...
# else:
#     statements
#     statements...
# ```
#
# ```python if,elif,else
# if(condition):
#     statement
# elif(condition):
#     statements
# elif(condition):
#     statement
# else:
#     statements..

# %%
#write a program to find the given number is even number 
num=int(input("please enter the number here:"))
if(num%2==0):
    print(num,"is even number")
# Out:
# please enter the number here: 22
# 22 is even number

# %%
#write a program to find the given number is even number or odd number
num=int(input("please enter the number here:"))
if(num%2==0):
    print(num,"is even number")
if(num%2!=0):
    print(num,"is odd number")
# Out:
# please enter the number here: 123
# 123 is odd number

# %%
#write a program to find the given number is positive or negitive or zero
num=int(input("please enter the number here:"))
if(num>0):
 print(num,"number is positive")
if(num<0):
 print(num,"number is negative")
if(num==0):
 print(num,"number is zero")
# Out:
# please enter the number here: 9
# 9 number is positive

# %%
"""
write a program to find the student grades basted on markes
1.if student marks in between 100 to 80 then grade is A
2.if student marks in between 79 to 60 then grade is B
3.if student marks in between 59 to 40 then grade is C
4.if student marks in between 39 to 25 then grade is D
5.if student marks in between 24 to 0 then grade is FAIl
6.if other than above marks expected output should be please enter correct marks
"""
marks=int(input("please enter the student marks here:"))
if(marks<=100 and marks>=80):
 print(marks,"grade A ")
elif(marks>=60 and marks>=79):
 print(marks,"grade B ")
elif(marks>=40 and marks>=59):
 print(marks,"grade C ")
elif(marks<=25 and marks>=39):
 print(marks,"grade D ")
elif(marks<=24 and marks>=0):
 print(marks,"grade FAIL ")
else:
  print(marks,"is not correct marks,please re-enter correct marks")
# Out:
# please enter the student marks here: 80
# 80 grade A

# %%
"""
write a program to find the largest number from three numbers
"""

num1=int(input("please enter the number here:"))
num2=int(input("please enter the number here:"))
num3=int(input("please enter the number here:"))
if(num1>num2 and num1>num3):
 print("num1 is the greatest among 3")
elif(num2>num3 and num2>num1):
 print("num2 is the greatest among 3")
elif(num3>num2 and num3>num1):
 print("num3 is the greatest among 3")
# Out:
# please enter the number here: 5
# please enter the number here: 1
# please enter the number here: 9
# num3 is the greatest among 3

# %% [markdown]
# ### +_--\ +Program to check if a year is a leap year
#
# # Input: year
# year = int(input("Enter a year: "))
#
# # Leap year conditions
# if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
#     print(year, "is a leap year.")
# else:
#     print(year, "is not a leap year.")

# %%
# Program to check login credentials

# Predefined username and password
correct_username = "admin"
correct_password = "12345"

# Input from user
username = input("Enter username: ")
password = input("Enter password: ")

# Check credentials
if username == correct_username and password == correct_password:
    print("Login successful!")
elif username != correct_username and password != correct_password:
    print("Both username and password are incorrect.")
elif username != correct_username:
    print("Incorrect username.")
else:
    print("Incorrect password.")
